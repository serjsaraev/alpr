# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1, 2, 4, 5"

# %%
import torch.backends.cudnn as cudnn
import yaml
from train import train
from utils import AttrDict
import pandas as pd
from datetime import date

# %%
def get_config(file_path):
    with open(file_path, 'r', encoding="utf8") as stream:
        opt = yaml.safe_load(stream)
    opt = AttrDict(opt)
    if opt.lang_char == 'None':
        characters = ''
        for data in opt['select_data'].split('-'):
            csv_path = os.path.join(opt['train_data'], data, 'labels.csv')
            df = pd.read_csv(csv_path, sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)
            all_char = ''.join(df['words'])
            characters += ''.join(set(all_char))
        characters = sorted(set(characters))
        opt.character= ''.join(characters)
    else:
        opt.character = opt.number + opt.symbol + opt.lang_char
    print(f"Количество символов: {len(opt.character)}")
    os.makedirs(f'./saved_models/{opt.experiment_name}', exist_ok=True)
    return opt

# %%
opt = get_config("config_files/ru_filtered_config.yaml")
train(opt, amp=False)
# Out:
# Количество символов: 34
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: all_data
# opt.select_data: ['train']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    all_data	 dataset: train
# all_data/train
# sub-directory:	/train	 num samples: 500000
# num total samples of train: 500000 x 1.0 (total_data_usage_ratio) = 500000
# num samples of train per batch: 1536 x 1.0 (batch_ratio) = 1536
# --------------------------------------------------------------------------------
# Total_batch_size: 1536 = 1536
# --------------------------------------------------------------------------------
# dataset_root:    all_data/val	 dataset: /
# all_data/val/
# sub-directory:	/.	 num samples: 50000
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 64 600 20 1 256 256 35 100000 None ResNet BiLSTM CTC
# loading pretrained model from saved_models/ru_filtered/best_accuracy.pth
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): ResNet_FeatureExtractor(
#       (ConvNet): ResNet(
#         (conv0_1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv0_2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer2): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool3): MaxPool2d(kernel_size=2, stride=(2, 1), padding=(0, 1), dilation=1, ceil_mode=False)
#         (layer3): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (3): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (4): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (layer4): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv4_1): Conv2d(256, 256, kernel_size=(2, 2), stride=(2, 1), padding=(0, 1), bias=False)
#         (bn4_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv4_2): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1), bias=False)
#         (bn4_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=35, bias=True)
#   )
# )
# Modules, Parameters
# module.FeatureExtraction.ConvNet.conv0_1.weight 144
# module.FeatureExtraction.ConvNet.bn0_1.weight 16
# module.FeatureExtraction.ConvNet.bn0_1.bias 16
# module.FeatureExtraction.ConvNet.conv0_2.weight 4608
# module.FeatureExtraction.ConvNet.bn0_2.weight 32
# module.FeatureExtraction.ConvNet.bn0_2.bias 32
# module.FeatureExtraction.ConvNet.layer1.0.conv1.weight 18432
# module.FeatureExtraction.ConvNet.layer1.0.bn1.weight 64
# module.FeatureExtraction.ConvNet.layer1.0.bn1.bias 64
# module.FeatureExtraction.ConvNet.layer1.0.conv2.weight 36864
# module.FeatureExtraction.ConvNet.layer1.0.bn2.weight 64
# module.FeatureExtraction.ConvNet.layer1.0.bn2.bias 64
# module.FeatureExtraction.ConvNet.layer1.0.downsample.0.weight 2048
# module.FeatureExtraction.ConvNet.layer1.0.downsample.1.weight 64
# module.FeatureExtraction.ConvNet.layer1.0.downsample.1.bias 64
# module.FeatureExtraction.ConvNet.conv1.weight 36864
# module.FeatureExtraction.ConvNet.bn1.weight 64
# module.FeatureExtraction.ConvNet.bn1.bias 64
# module.FeatureExtraction.ConvNet.layer2.0.conv1.weight 73728
# module.FeatureExtraction.ConvNet.layer2.0.bn1.weight 128
# module.FeatureExtraction.ConvNet.layer2.0.bn1.bias 128
# module.FeatureExtraction.ConvNet.layer2.0.conv2.weight 147456
# module.FeatureExtraction.ConvNet.layer2.0.bn2.weight 128
# module.FeatureExtraction.ConvNet.layer2.0.bn2.bias 128
# module.FeatureExtraction.ConvNet.layer2.0.downsample.0.weight 8192
# module.FeatureExtraction.ConvNet.layer2.0.downsample.1.weight 128
# module.FeatureExtraction.ConvNet.layer2.0.downsample.1.bias 128
# module.FeatureExtraction.ConvNet.layer2.1.conv1.weight 147456
# module.FeatureExtraction.ConvNet.layer2.1.bn1.weight 128
# module.FeatureExtraction.ConvNet.layer2.1.bn1.bias 128
# module.FeatureExtraction.ConvNet.layer2.1.conv2.weight 147456
# module.FeatureExtraction.ConvNet.layer2.1.bn2.weight 128
# module.FeatureExtraction.ConvNet.layer2.1.bn2.bias 128
# module.FeatureExtraction.ConvNet.conv2.weight 147456
# module.FeatureExtraction.ConvNet.bn2.weight 128
# module.FeatureExtraction.ConvNet.bn2.bias 128
# module.FeatureExtraction.ConvNet.layer3.0.conv1.weight 294912
# module.FeatureExtraction.ConvNet.layer3.0.bn1.weight 256
# module.FeatureExtraction.ConvNet.layer3.0.bn1.bias 256
# module.FeatureExtraction.ConvNet.layer3.0.conv2.weight 589824
# module.FeatureExtraction.ConvNet.layer3.0.bn2.weight 256
# module.FeatureExtraction.ConvNet.layer3.0.bn2.bias 256
# module.FeatureExtraction.ConvNet.layer3.0.downsample.0.weight 32768
# module.FeatureExtraction.ConvNet.layer3.0.downsample.1.weight 256
# module.FeatureExtraction.ConvNet.layer3.0.downsample.1.bias 256
# module.FeatureExtraction.ConvNet.layer3.1.conv1.weight 589824
# module.FeatureExtraction.ConvNet.layer3.1.bn1.weight 256
# module.FeatureExtraction.ConvNet.layer3.1.bn1.bias 256
# module.FeatureExtraction.ConvNet.layer3.1.conv2.weight 589824
# module.FeatureExtraction.ConvNet.layer3.1.bn2.weight 256
# module.FeatureExtraction.ConvNet.layer3.1.bn2.bias 256
# module.FeatureExtraction.ConvNet.layer3.2.conv1.weight 589824
# module.FeatureExtraction.ConvNet.layer3.2.bn1.weight 256
# module.FeatureExtraction.ConvNet.layer3.2.bn1.bias 256
# module.FeatureExtraction.ConvNet.layer3.2.conv2.weight 589824
# module.FeatureExtraction.ConvNet.layer3.2.bn2.weight 256
# module.FeatureExtraction.ConvNet.layer3.2.bn2.bias 256
# module.FeatureExtraction.ConvNet.layer3.3.conv1.weight 589824
# module.FeatureExtraction.ConvNet.layer3.3.bn1.weight 256
# module.FeatureExtraction.ConvNet.layer3.3.bn1.bias 256
# module.FeatureExtraction.ConvNet.layer3.3.conv2.weight 589824
# module.FeatureExtraction.ConvNet.layer3.3.bn2.weight 256
# module.FeatureExtraction.ConvNet.layer3.3.bn2.bias 256
# module.FeatureExtraction.ConvNet.layer3.4.conv1.weight 589824
# module.FeatureExtraction.ConvNet.layer3.4.bn1.weight 256
# module.FeatureExtraction.ConvNet.layer3.4.bn1.bias 256
# module.FeatureExtraction.ConvNet.layer3.4.conv2.weight 589824
# module.FeatureExtraction.ConvNet.layer3.4.bn2.weight 256
# module.FeatureExtraction.ConvNet.layer3.4.bn2.bias 256
# module.FeatureExtraction.ConvNet.conv3.weight 589824
# module.FeatureExtraction.ConvNet.bn3.weight 256
# module.FeatureExtraction.ConvNet.bn3.bias 256
# module.FeatureExtraction.ConvNet.layer4.0.conv1.weight 589824
# module.FeatureExtraction.ConvNet.layer4.0.bn1.weight 256
# module.FeatureExtraction.ConvNet.layer4.0.bn1.bias 256
# module.FeatureExtraction.ConvNet.layer4.0.conv2.weight 589824
# module.FeatureExtraction.ConvNet.layer4.0.bn2.weight 256
# module.FeatureExtraction.ConvNet.layer4.0.bn2.bias 256
# module.FeatureExtraction.ConvNet.layer4.1.conv1.weight 589824
# module.FeatureExtraction.ConvNet.layer4.1.bn1.weight 256
# module.FeatureExtraction.ConvNet.layer4.1.bn1.bias 256
# module.FeatureExtraction.ConvNet.layer4.1.conv2.weight 589824
# module.FeatureExtraction.ConvNet.layer4.1.bn2.weight 256
# module.FeatureExtraction.ConvNet.layer4.1.bn2.bias 256
# module.FeatureExtraction.ConvNet.layer4.2.conv1.weight 589824
# module.FeatureExtraction.ConvNet.layer4.2.bn1.weight 256
# module.FeatureExtraction.ConvNet.layer4.2.bn1.bias 256
# module.FeatureExtraction.ConvNet.layer4.2.conv2.weight 589824
# module.FeatureExtraction.ConvNet.layer4.2.bn2.weight 256
# module.FeatureExtraction.ConvNet.layer4.2.bn2.bias 256
# module.FeatureExtraction.ConvNet.conv4_1.weight 262144
# module.FeatureExtraction.ConvNet.bn4_1.weight 256
# module.FeatureExtraction.ConvNet.bn4_1.bias 256
# module.FeatureExtraction.ConvNet.conv4_2.weight 262144
# module.FeatureExtraction.ConvNet.bn4_2.weight 256
# module.FeatureExtraction.ConvNet.bn4_2.bias 256
# module.SequenceModeling.0.rnn.weight_ih_l0 262144
# module.SequenceModeling.0.rnn.weight_hh_l0 262144
# module.SequenceModeling.0.rnn.bias_ih_l0 1024
# module.SequenceModeling.0.rnn.bias_hh_l0 1024
# module.SequenceModeling.0.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.0.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.0.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.0.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.0.linear.weight 131072
# module.SequenceModeling.0.linear.bias 256
# module.SequenceModeling.1.rnn.weight_ih_l0 262144
# module.SequenceModeling.1.rnn.weight_hh_l0 262144
# module.SequenceModeling.1.rnn.bias_ih_l0 1024
# module.SequenceModeling.1.rnn.bias_hh_l0 1024
# module.SequenceModeling.1.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.1.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.1.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.1.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.1.linear.weight 131072
# module.SequenceModeling.1.linear.bias 256
# module.Prediction.weight 8960
# module.Prediction.bias 35
# Total Trainable Params: 13449235
# Trainable params num :  13449235
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     lr: 1.0
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# number:
# symbol:
# lang_char: абвгдеёжзийклмнопрстуфхцчшщъыьэюя
# experiment_name: ru_filtered
# train_data: all_data
# valid_data: all_data/val
# manualSeed: 1111
# workers: 64
# batch_size: 1536
# num_iter: 50000
# valInterval: 50
# saved_model: saved_models/ru_filtered/best_accuracy.pth
# FT: False
# optim: Adam
# lr: 1.0
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# select_data: ['train']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 100000
# imgH: 64
# imgW: 600
# rgb: False
# contrast_adjust: 0.0
# sensitive: True
# PAD: True
# data_filtering_off: False
# Transformation: None
# FeatureExtraction: ResNet
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 1
# output_channel: 256
# hidden_size: 256
# decode: greedy
# new_prediction: False
# freeze_FeatureFxtraction: False
# freeze_SequenceModeling: False
# character:  абвгдеёжзийклмнопрстуфхцчшщъыьэюя
# num_class: 35
# ---------------------------------------
#
# Start training
# training time:  151.70438766479492
# [50/50000] Train loss: 0.02225, Valid loss: 0.07211, Elapsed_time: 151.70464
# Current_accuracy : 77.228, Current_norm_ED  : 0.9819
# Best_accuracy    : 77.228, Best_norm_ED     : 0.9819
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# тигельной аэролифтом недослышанными | тигельной аэролифтом недослышанными | 0.0576	True
# четырёхэтажным сложноподчинённый контрактам пикратам перепруживаемые | четырепотемьта сложнопоочинённый крстреннам паоратая переприжираемый | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  429.9054605960846
# training time:  116.3916187286377
# [100/50000] Train loss: 0.02239, Valid loss: 0.07286, Elapsed_time: 698.00195
# Current_accuracy : 77.392, Current_norm_ED  : 0.9819
# Best_accuracy    : 77.392, Best_norm_ED     : 0.9819
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# запечатанную останавливавшими гипертоников вживление стеклокристаллического | оопечатенную останавливавшими гипертоников вживление стеклокристаллического | 0.0002	False
# предопределивших залившая отыскиваемою послушала впутывание | предопределивших залившая отыскиваемою послушала впутывание | 0.0393	True
# --------------------------------------------------------------------------------
# validation time:  421.3265495300293
# training time:  116.41552376747131
# [150/50000] Train loss: 0.02250, Valid loss: 0.07789, Elapsed_time: 1235.74450
# Current_accuracy : 76.302, Current_norm_ED  : 0.9809
# Best_accuracy    : 77.392, Best_norm_ED     : 0.9819
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# перезревающий разведенкам анархистскую накляу вальцовочной | перезревающий разведенкам анархистскую накляувальцовочной | 0.0243	False
# отсеивающуюся вдолблённая плагиаторство изучать | отсеивающуюся вдолблённая плагиаторство изучать | 0.1136	True
# --------------------------------------------------------------------------------
# validation time:  417.0230519771576
# training time:  115.60978412628174
# [200/50000] Train loss: 0.02399, Valid loss: 0.07384, Elapsed_time: 1768.37765
# Current_accuracy : 76.752, Current_norm_ED  : 0.9816
# Best_accuracy    : 77.392, Best_norm_ED     : 0.9819
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# умозаключаешь теплоотражательное разбраковывавшие чих скандальозностей | умозакллчаешь теплоотражательное разбраковывавшие чих скандальозностей | 0.0035	False
# укреплявшимися реорганизовываемыми преподнесёнными самоочищающийся зачитываемою | ураниовшаю реогамиковывммими дотелиалныны ваинтовшим мнтимыяос | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  426.51480197906494
# training time:  115.75684261322021
# [250/50000] Train loss: 0.02219, Valid loss: 0.07657, Elapsed_time: 2310.64970
# Current_accuracy : 76.750, Current_norm_ED  : 0.9813
# Best_accuracy    : 77.392, Best_norm_ED     : 0.9819
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# голубеводы поплёвывавшие палеогена | голубеводы поплёвывавшие палеогена | 0.0255	True
# скачайте вогульская утюженую расцепляющих | скачайте вогульская утюженую расцепляющих | 0.2021	True
# --------------------------------------------------------------------------------
# validation time:  416.8052444458008
# training time:  116.09613227844238
# [300/50000] Train loss: 0.02285, Valid loss: 0.07776, Elapsed_time: 2843.55165
# Current_accuracy : 76.134, Current_norm_ED  : 0.9809
# Best_accuracy    : 77.392, Best_norm_ED     : 0.9819
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ателектаза олимпийским галоидная | ателектаза олимпийским галоидная | 0.1348	True
# лоточному низведением беззастенчивую отображающего | лоточному низведением беззастенчивую отображающего | 0.0494	True
# --------------------------------------------------------------------------------
# validation time:  421.65846943855286
# training time:  134.7596983909607
# [350/50000] Train loss: 0.02123, Valid loss: 0.07500, Elapsed_time: 3399.97121
# Current_accuracy : 77.560, Current_norm_ED  : 0.9820
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9820
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# галереею графичности умещавшееся | галереею графичности умещавшееся | 0.0832	True
# хими пенджабом паутина империалистское | хими пенджабом паутина империалистское | 0.0980	True
# --------------------------------------------------------------------------------
# validation time:  420.3364152908325
# training time:  115.96325945854187
# [400/50000] Train loss: 0.01903, Valid loss: 0.07713, Elapsed_time: 3936.27114
# Current_accuracy : 77.032, Current_norm_ED  : 0.9818
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9820
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# осветлило долеченную кандидатуры уравновешивают басовитою | осветлило долеченную напдидатусы уравнавешиемот баговитою | 0.0001	False
# дееспособным отвалкою почтившая | дееспособным отвалкою почтившая | 0.1997	True
# --------------------------------------------------------------------------------
# validation time:  419.8979411125183
# training time:  116.10127997398376
# [450/50000] Train loss: 0.01945, Valid loss: 0.09278, Elapsed_time: 4472.27083
# Current_accuracy : 72.500, Current_norm_ED  : 0.9779
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9820
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# пробегаем бромсукцинимиду догуливающая подстригался | пробегаем бромсукцинимиду догуливающая подстригался | 0.0149	True
# припудрится привадил заядлом приуменьшённому завиваемуюмедлимобод | припудрится привадил заядлом приуменьшённому завиваемуюмедлимобод | 0.2569	True
# --------------------------------------------------------------------------------
# validation time:  423.823655128479
# training time:  116.33099842071533
# [500/50000] Train loss: 0.02100, Valid loss: 0.07620, Elapsed_time: 5012.42570
# Current_accuracy : 76.772, Current_norm_ED  : 0.9812
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9820
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# фишкой газогенераторного вагонетка воспитателю | фишкой газогенераторного вагонетка воспитателю | 0.1177	True
# отвердеют ведет упаковывавшейся глючных | отвердеют ведет упаковывавшейся глючных | 0.0674	True
# --------------------------------------------------------------------------------
# validation time:  420.13725066185
# training time:  116.43358373641968
# [550/50000] Train loss: 0.02022, Valid loss: 0.08132, Elapsed_time: 5548.99673
# Current_accuracy : 76.860, Current_norm_ED  : 0.9811
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9820
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# углекопу перешагнут рубиновом | углекопу перешагнут рубиновом | 0.1300	True
# анкилостома электропил мезосферой | анкилостома электропил мезосферой | 0.1082	True
# --------------------------------------------------------------------------------
# validation time:  450.24754190444946
# training time:  116.28256797790527
# [600/50000] Train loss: 0.02133, Valid loss: 0.08164, Elapsed_time: 6115.52716
# Current_accuracy : 75.960, Current_norm_ED  : 0.9807
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9820
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# загромождающая пожаперекалявшихинд земледельческих подготавливаемыми | загромождающая пожаперекалявшихинд земледельческих подготавливаемыми | 0.2816	True
# неубранным предреченый лексикографического фальсификаторов схоронила | неубранным предреченый лексикографического фальсификаторов схоронила | 0.8000	True
# --------------------------------------------------------------------------------
# validation time:  476.9168846607208
# training time:  115.67104935646057
# [650/50000] Train loss: 0.02356, Valid loss: 0.07620, Elapsed_time: 6708.11578
# Current_accuracy : 77.150, Current_norm_ED  : 0.9818
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9820
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# сокровище впрыгнувшими выкрадываемою ото | сокровище впрыгнувшими выкрадываемою ото | 0.0638	True
# компостировались лифтовом корчевального | компостировались лифтовом корчевального | 0.2065	True
# --------------------------------------------------------------------------------
# validation time:  495.43970131874084
# training time:  130.25564646720886
# [700/50000] Train loss: 0.01737, Valid loss: 0.07937, Elapsed_time: 7333.81151
# Current_accuracy : 77.300, Current_norm_ED  : 0.9818
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9820
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# гадолиниевою подвозкой формалистичная бережёномуалупкински флердоранжевым | галолиниевою подвозкой формалистичная бережёномуалупкински флердоранжевым | 0.2225	False
# совлеченная архангельцу зоопсихологами сванка уговаривайте | совлеченная архангельцу зоопсихологами сванка уговаривайте | 0.0120	True
# --------------------------------------------------------------------------------
# validation time:  679.6172096729279
# training time:  115.56473112106323
# [750/50000] Train loss: 0.01822, Valid loss: 0.09134, Elapsed_time: 8128.99367
# Current_accuracy : 76.186, Current_norm_ED  : 0.9804
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9820
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ретроспективная обносок брудергауза ленинградцами | ретроспективная обносок брудергауза ленинградцами | 0.0514	True
# занавешиваем заготавливающих вертимся галлюцинировавшей | занавешиваем заготавливающих вертимся галлюцинировавшей | 0.0152	True
# --------------------------------------------------------------------------------
# validation time:  506.6154057979584
# training time:  115.94871187210083
# [800/50000] Train loss: 0.01810, Valid loss: 0.07684, Elapsed_time: 8751.55802
# Current_accuracy : 77.296, Current_norm_ED  : 0.9821
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9821
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# сопоставившие налаживавшаяся пятнах замываясь | сопоставившие налаживавшаяся пятнах замываясь | 0.0423	True
# старте отговариванию обеливавшая | старте отговариванию обеливавшая | 0.0974	True
# --------------------------------------------------------------------------------
# validation time:  473.20243430137634
# training time:  116.6138243675232
# [850/50000] Train loss: 0.01881, Valid loss: 0.07751, Elapsed_time: 9341.37452
# Current_accuracy : 77.452, Current_norm_ED  : 0.9821
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9821
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# недост приключившейся дотрётся поборовшийся | недост приключившейся дотрётся поборовшийся | 0.0960	True
# вмазывать оббегаешь деньжищ перемахивающему | вмазывать оббегаешь деньжищ перемахивающему | 0.1218	True
# --------------------------------------------------------------------------------
# validation time:  465.4327676296234
# training time:  115.71486139297485
# [900/50000] Train loss: 0.02084, Valid loss: 0.07873, Elapsed_time: 9922.52237
# Current_accuracy : 76.350, Current_norm_ED  : 0.9813
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9821
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# хрипловатую обделившие пасынкован битной наполнившимся | хрипловатую обделившие пасынкован битной наполнившимся | 0.2934	True
# бескрайный грозоотметчиках закряхтевшем оценивающих обольстителя | бескрайный грозоотметчиках закряхтевшем оценивающих обольстителя | 0.0351	True
# --------------------------------------------------------------------------------
# validation time:  471.3348083496094
# training time:  115.808114528656
# [950/50000] Train loss: 0.01942, Valid loss: 0.07680, Elapsed_time: 10509.66552
# Current_accuracy : 77.066, Current_norm_ED  : 0.9818
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9821
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# отмахивавшемся костылезабивщику септолью | отмахивавшемся костылезабивщику септолью | 0.1108	True
# аннотированы хорватском лущильного газосварщикумотыж | аннотированы хорватском лущильного газосварщикумотыж | 0.0517	True
# --------------------------------------------------------------------------------
# validation time:  470.75702595710754
# training time:  135.83727049827576
# [1000/50000] Train loss: 0.01950, Valid loss: 0.08021, Elapsed_time: 11116.26023
# Current_accuracy : 77.282, Current_norm_ED  : 0.9819
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9821
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# занявшаясяобстроилодо перхали перевербовывающую выковкою певучей | занявшаясяобстроилодо перхали перевербовывающую выковкою певучей | 0.0791	True
# повторный детандере наращиваемого | повторный детандере наращиваемого | 0.1344	True
# --------------------------------------------------------------------------------
# validation time:  471.03376030921936
# training time:  116.72790193557739
# [1050/50000] Train loss: 0.01645, Valid loss: 0.08072, Elapsed_time: 11704.02264
# Current_accuracy : 76.928, Current_norm_ED  : 0.9817
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9821
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# крупой галлицизмом заборонено процеживальщик танкострои | крупой галлицизмом заборонено процеживальщик танкострои | 0.0627	True
# фельетонного завинчивающее трёхкаскадном проващивайте лещиною | фельетонного завинчивающее трёхкаскадном проващивайте лещиною | 0.0381	True
# --------------------------------------------------------------------------------
# validation time:  466.1564943790436
# training time:  116.67344951629639
# [1100/50000] Train loss: 0.01711, Valid loss: 0.08513, Elapsed_time: 12286.85295
# Current_accuracy : 76.746, Current_norm_ED  : 0.9814
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9821
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# жалостливого визжавшее варнаки | жалостливого визжавшее варнаки | 0.1844	True
# веслахст уязвимой орденским эстетству погорельская | веслахст уязвимой орденским эстетству погорельская | 0.0707	True
# --------------------------------------------------------------------------------
# validation time:  440.3336372375488
# training time:  116.6563835144043
# [1150/50000] Train loss: 0.01758, Valid loss: 0.08049, Elapsed_time: 12843.84340
# Current_accuracy : 77.100, Current_norm_ED  : 0.9818
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9821
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# растворивших защитами отбыватьполуулыбкеутёк прижмуривавшейся хилую | растворивших защигами отбыватьполулыбкаузёк прижмуривавшейся хиную | 0.0016	False
# псаломная просовывай вколачи досыпетсясбесившуюся | псаломная просовывай вколачи досыпетсясбесившуюся | 0.0458	True
# --------------------------------------------------------------------------------
# validation time:  448.41064977645874
# training time:  116.00369381904602
# [1200/50000] Train loss: 0.01756, Valid loss: 0.07800, Elapsed_time: 13408.25870
# Current_accuracy : 77.136, Current_norm_ED  : 0.9819
# Best_accuracy    : 77.560, Best_norm_ED     : 0.9821
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# серопесчаном переписному двухзональную | серопесчаном переписному двухзональную | 0.2061	True
# отщёлкиваете издольщиком откопанную чешкам магнетизированного | отщёлкиваете издольщиком откопанную чешкам магнетизированного | 0.2705	True
# --------------------------------------------------------------------------------
# validation time:  438.097697019577
# training time:  115.61434173583984
# [1250/50000] Train loss: 0.01757, Valid loss: 0.08054, Elapsed_time: 13961.97095
# Current_accuracy : 77.596, Current_norm_ED  : 0.9822
# Best_accuracy    : 77.596, Best_norm_ED     : 0.9822
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# приказанная приселёно крепчает отвоевываем якшающимся | приказанная приселёно крепчает отвоевываем якишающимся | 0.0379	False
# разгребены отгонявшимся спутниковом каламбурило | разгребены отгонявшимся спутниковом каламбурило | 0.0408	True
# --------------------------------------------------------------------------------
# validation time:  435.9792594909668
# training time:  115.64683961868286
# [1300/50000] Train loss: 0.01928, Valid loss: 0.08153, Elapsed_time: 14513.59728
# Current_accuracy : 76.804, Current_norm_ED  : 0.9813
# Best_accuracy    : 77.596, Best_norm_ED     : 0.9822
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# обезличивавшиеся неназванной воображавшемузавозившимс | обезличивавшиеся неназванной воображавшемузавозившимс | 0.0764	True
# инсорит покалечившее амортизиров притягивавшимися | инсорит покалечившее амортизиров притягивавшимися | 0.1195	True
# --------------------------------------------------------------------------------
# validation time:  439.0828049182892
# training time:  134.63867259025574
# [1350/50000] Train loss: 0.01519, Valid loss: 0.09553, Elapsed_time: 15087.31963
# Current_accuracy : 74.530, Current_norm_ED  : 0.9795
# Best_accuracy    : 77.596, Best_norm_ED     : 0.9822
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# арилзамещенные пискленку факельцуга неопрятнейшем межзонному | арилзамещенные пискленку факельцуга неопрятнейшем межзонному | 0.0233	True
# цапнула моечными перекусываешь салтыкова заевшие | цапнула моечными перекусываешь салтыкова заевшие | 0.0098	True
# --------------------------------------------------------------------------------
# validation time:  425.84814858436584
# training time:  116.61146426200867
# [1400/50000] Train loss: 0.08556, Valid loss: 0.07070, Elapsed_time: 15629.77951
# Current_accuracy : 77.358, Current_norm_ED  : 0.9822
# Best_accuracy    : 77.596, Best_norm_ED     : 0.9822
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# перекурившей самовосхваления вывалявшись пополоскают удостоверяемых | перекурившей самовосхваления вывалявшись пополоскают удостоверяемых | 0.1450	True
# сталелитейщику истошные ильинской общекультурные | сталелитейщику истошные ильинской общекультурные | 0.0225	True
# --------------------------------------------------------------------------------
# validation time:  422.6991424560547
# training time:  116.43239760398865
# [1450/50000] Train loss: 0.01767, Valid loss: 0.07810, Elapsed_time: 16168.91195
# Current_accuracy : 76.732, Current_norm_ED  : 0.9816
# Best_accuracy    : 77.596, Best_norm_ED     : 0.9822
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# индивидуалистскиесви аденскою спецэффектахотпилива транслирующеюся целлоновыхшейкойпереувл | идитдралистетнест аденскою стерофектахошнилися тражелирующеюся целлетовыхшейкойнереуел | 0.0000	False
# мышечных хлевами явлены   | мышечных хлевами явлены   | 0.1107	True
# --------------------------------------------------------------------------------
# validation time:  418.22840881347656
# training time:  115.84064865112305
